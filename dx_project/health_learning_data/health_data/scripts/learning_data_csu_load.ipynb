# %%
from update_package.csu_system_health_algorithms import apply_system_health_algorithms_with_csu
from update_package.select_dataset import get_dataframe_from_database
from update_package.load_database import load_database

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from update_package.csu_system_health_algorithms import apply_system_health_algorithms_with_csu
#       2 from update_package.select_dataset import get_dataframe_from_database
#       3 from update_package.load_database import load_database
#
# ModuleNotFoundError: No module named 'update_package'

# %%
# Goals: 정상 데이터 목록화

latest_data = pd.read_csv(r"C:\Users\pc021\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\data\latest\ecs_data.csv")
data = pd.read_csv(r"C:\Users\pc021\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\data\ecs_DATA.csv")

grouped_latest_data = latest_data.groupby(['SHIP_ID','OP_INDEX','SECTION']).count() 
grouped_latest_index = grouped_latest_data.index

grouped_data = data.groupby(['SHIP_ID','OP_INDEX','SECTION']).count() 
grouped_index = grouped_data.index

multiindex2_without_overlap = grouped_latest_index.difference(grouped_index)

# %%
datas = pd.DataFrame(index = multiindex2_without_overlap).reset_index()
datas[(datas['SHIP_ID']=='T150914-00202') & (datas['OP_INDEX']==26) & (datas['SECTION']==0)]
# Out:
#             SHIP_ID  OP_INDEX  SECTION
# 7251  T150914-00202        26        0

# %%
for index in multiindex2_without_overlap[7251:]:
    ship_id = index[0]
    op_index = index[1]
    section = index[2] 
    
    #data = get_dataframe_from_database(ship_id,op_index,section)
    df = latest_data[(latest_data['SHIP_ID']==ship_id) & (latest_data['OP_INDEX']==op_index) & (latest_data['SECTION']==section)]
    
    data_len = len(df)
    
    print(f'SHIP_ID : {ship_id} / OP_INDEX : {op_index} / SECTION : {section} -  데이터 선택 ({data_len})')
    
    if (data_len>=100) :
        print(f'SHIP_ID : {ship_id} / OP_INDEX : {op_index} / SECTION : {section} -  조건 통과')
        try:
            apply_system_health_algorithms_with_csu(ship_id,op_index,section)
        except ValueError as e :
            print(f'에러 발생: {e}. 다음 반복으로 넘어갑니다.')
            continue  # 에러 발생 시 다음 반복으로 넘어감\
            
        except KeyError as e :
            print(f'에러 발생: {e}. 다음 반복으로 넘어갑니다.')
            continue  # 에러 발생 시 다음 반복으로 넘어감
# Out:
# SHIP_ID : T150914-00202 / OP_INDEX : 26 / SECTION : 0 -  데이터 선택 (105)
# SHIP_ID : T150914-00202 / OP_INDEX : 26 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_csu_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_csu_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T150914-00202 / OP_INDEX : 27 / SECTION : 0 -  데이터 선택 (72)
# SHIP_ID : T150914-00202 / OP_INDEX : 28 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T150914-00202 / OP_INDEX : 29 / SECTION : 0 -  데이터 선택 (39)
# SHIP_ID : T150914-00202 / OP_INDEX : 30 / SECTION : 0 -  데이터 선택 (71)
# SHIP_ID : T150914-00202 / OP_INDEX : 31 / SECTION : 0 -  데이터 선택 (57)
# SHIP_ID : T150914-00202 / OP_INDEX : 32 / SECTION : 0 -  데이터 선택 (77)
# SHIP_ID : T150914-00202 / OP_INDEX : 33 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150914-00202 / OP_INDEX : 34 / SECTION : 0 -  데이터 선택 (71)
# SHIP_ID : T150914-00202 / OP_INDEX : 35 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T150914-00202 / OP_INDEX : 36 / SECTION : 0 -  데이터 선택 (3)
# SHIP_ID : T150914-00202 / OP_INDEX : 37 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T150914-00202 / OP_INDEX : 38 / SECTION : 0 -  데이터 선택 (85)
# SHIP_ID : T150914-00202 / OP_INDEX : 39 / SECTION : 0 -  데이터 선택 (262)
# SHIP_ID : T150914-00202 / OP_INDEX : 39 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T150914-00202 / OP_INDEX : 40 / SECTION : 0 -  데이터 선택 (125)
# SHIP_ID : T150914-00202 / OP_INDEX : 40 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T150914-00202 / OP_INDEX :
system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T150922-01101 / OP_INDEX : 353 / SECTION : 0 -  데이터 선택 (72)
# SHIP_ID : T150922-01101 / OP_INDEX : 354 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 355 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T150922-01101 / OP_INDEX : 356 / SECTION : 0 -  데이터 선택 (64)
# SHIP_ID : T150922-01101 / OP_INDEX : 357 / SECTION : 0 -  데이터 선택 (76)
# SHIP_ID : T150922-01101 / OP_INDEX : 358 / SECTION : 0 -  데이터 선택 (93)
# SHIP_ID : T150922-01101 / OP_INDEX : 359 / SECTION : 0 -  데이터 선택 (28)
# SHIP_ID : T150922-01101 / OP_INDEX : 360 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 361 / SECTION : 0 -  데이터 선택 (15)
# SHIP_ID : T150922-01101 / OP_INDEX : 362 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T150922-01101 / OP_INDEX : 363 / SECTION : 0 -  데이터 선택 (15)
# SHIP_ID : T150922-01101 / OP_INDEX : 364 / SECTION : 0 -  데이터 선택 (11)
# SHIP_ID : T150922-01101 / OP_INDEX : 365 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 366 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T150922-01101 / OP_INDEX : 367 / SECTION : 0 -  데이터 선택 (66)
# SHIP_ID : T150922-01101 / OP_INDEX : 368 / SECTION : 0 -  데이터 선택 (11)
# SHIP_ID : T150922-01101 / OP_INDEX : 369 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T150922-01101 / OP_INDEX : 370 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T150922-01101 / OP_INDEX : 371 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T150922-01101 / OP_INDEX : 372 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 373 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 374 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 375 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 376 / SECTION : 0 -  데이터 선택 (22)
# SHIP_ID : T150922-01101 / OP_INDEX : 377 / SECTION : 0 -  데이터 선택 (23)
# SHIP_ID : T150922-01101 / OP_INDEX : 378 / SECTION : 0 -  데이터 선택 (25)
# SHIP_ID : T150922-01101 / OP_INDEX : 379 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 380 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 381 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 382 / SECTION : 0 -  데이터 선택 (23)
# SHIP_ID : T150922-01101 / OP_INDEX : 383 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 384 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 385 / SECTION : 0 -  데이터 선택 (23)
# SHIP_ID : T150922-01101 / OP_INDEX : 386 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T150922-01101 / OP_INDEX : 387 / SECTION : 0 -  데이터 선택 (62)
# SHIP_ID : T150922-01101 / OP_INDEX : 388 / SECTION : 0 -  데이터 선택 (38)
# SHIP_ID : T150922-01101 / OP_INDEX : 389 / SECTION : 0 -  데이터 선택 (39)
# SHIP_ID : T150922-01101 / OP_INDEX : 390 / SECTION : 0 -  데이터 선택 (160)
# SHIP_ID : T150922-01101 / OP_INDEX : 390 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T150922-01101 / OP_INDEX : 391 / SECTION : 0 -  데이터 선택 (62)
# SHIP_ID : T150922-01101 / OP_INDEX : 392 / SECTION : 0 -  데이터 선택 (43)
# SHIP_ID : T150922-01101 / OP_INDEX : 393 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 394 / SECTION : 0 -  데이터 선택 (51)
# SHIP_ID : T150922-01101 / OP_INDEX : 395 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 396 / SECTION : 0 -  데이터 선택 (11)
# SHIP_ID : T150922-01101 / OP_INDEX : 397 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 398 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 399 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 400 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 401 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 402 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 403 / SECTION : 0 -  데이터 선택 (25)
# SHIP_ID : T150922-01101 / OP_INDEX : 404 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T150922-01101 / OP_INDEX : 405 / SECTION : 0 -  데이터 선택 (29)
# SHIP_ID : T150922-01101 / OP_INDEX : 411 / SECTION : 0 -  데이터 선택 (17)
# SHIP_ID : T150922-01101 / OP_INDEX : 412 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 413 / SECTION : 0 -  데이터 선택 (23)
# SHIP_ID : T150922-01101 / OP_INDEX : 414 / SECTION : 0 -  데이터 선택 (33)
# SHIP_ID : T150922-01101 / OP_INDEX : 415 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 416 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 417 / SECTION : 0 -  데이터 선택 (29)
# SHIP_ID : T150922-01101 / OP_INDEX : 418 / SECTION : 0 -  데이터 선택 (43)
# SHIP_ID : T150922-01101 / OP_INDEX : 419 / SECTION : 0 -  데이터 선택 (36)
# SHIP_ID : T150922-01101 / OP_INDEX : 420 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 421 / SECTION : 0 -  데이터 선택 (29)
# SHIP_ID : T150922-01101 / OP_INDEX : 422 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 423 / SECTION : 0 -  데이터 선택 (23)
# SHIP_ID : T150922-01101 / OP_INDEX : 424 / SECTION : 0 -  데이터 선택 (44)
# SHIP_ID : T150922-01101 / OP_INDEX : 425 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 426 / SECTION : 0 -  데이터 선택 (21)
# SHIP_ID : T150922-01101 / OP_INDEX : 427 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T150922-01101 / OP_INDEX : 428 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 429 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 430 / SECTION : 0 -  데이터 선택 (17)
# SHIP_ID : T150922-01101 / OP_INDEX : 431 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 432 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 433 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 434 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 435 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 436 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 437 / SECTION : 0 -  데이터 선택 (20)
# SHIP_ID : T150922-01101 / OP_INDEX : 438 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 439 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 440 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 441 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 442 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T150922-01101 / OP_INDEX : 443 / SECTION : 0 -  데이터 선택 (65)
# SHIP_ID : T150922-01101 / OP_INDEX : 444 / SECTION : 0 -  데이터 선택 (83)
# SHIP_ID : T150922-01101 / OP_INDEX : 446 / SECTION : 0 -  데이터 선택 (180)
# SHIP_ID : T150922-01101 / OP_INDEX : 446 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T150922-01101 / OP_INDEX : 447 / SECTION : 0 -  데이터 선택 (177)
# SHIP_ID : T150922-01101 / OP_INDEX : 447 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T150922-01101 / OP_INDEX : 448 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T150922-01101 / OP_INDEX : 449 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 450 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX : 451 / SECTION : 0 -  데이터 선택 (16)
# SHIP_ID : T150922-01101 / OP_INDEX : 452 / SECTION : 0 -  데이터 선택 (21)
# SHIP_ID : T150922-01101 / OP_INDEX : 453 / SECTION : 0 -  데이터 선택 (18)
# SHIP_ID : T150922-01101 / OP_INDEX :
/ SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 494 / SECTION : 0 -  데이터 선택 (111)
# SHIP_ID : T20210730002 / OP_INDEX : 494 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 495 / SECTION : 0 -  데이터 선택 (114)
# SHIP_ID : T20210730002 / OP_INDEX : 495 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 496 / SECTION : 0 -  데이터 선택 (15)
# SHIP_ID : T20210730002 / OP_INDEX : 497 / SECTION : 0 -  데이터 선택 (492)
# SHIP_ID : T20210730002 / OP_INDEX : 497 / SECTION : 0 -  조건 통과
# OP_TYPE:4 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 498 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T20210730002 / OP_INDEX : 499 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 500 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 506 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 507 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 508 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 509 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 510 / SECTION : 0 -  데이터 선택 (15)
# SHIP_ID : T20210730002 / OP_INDEX : 511 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 512 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210730002 / OP_INDEX : 513 / SECTION : 0 -  데이터 선택 (11)
# SHIP_ID : T20210730002 / OP_INDEX : 514 / SECTION : 0 -  데이터 선택 (93)
# SHIP_ID : T20210730002 / OP_INDEX : 515 / SECTION : 0 -  데이터 선택 (80)
# SHIP_ID : T20210730002 / OP_INDEX : 518 / SECTION : 0 -  데이터 선택 (54)
# SHIP_ID : T20210730002 / OP_INDEX : 519 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 520 / SECTION : 0 -  데이터 선택 (464)
# SHIP_ID : T20210730002 / OP_INDEX : 520 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 521 / SECTION : 0 -  데이터 선택 (15)
# SHIP_ID : T20210730002 / OP_INDEX : 538 / SECTION : 0 -  데이터 선택 (34)
# SHIP_ID : T20210730002 / OP_INDEX : 539 / SECTION : 0 -  데이터 선택 (327)
# SHIP_ID : T20210730002 / OP_INDEX : 539 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 540 / SECTION : 0 -  데이터 선택 (365)
# SHIP_ID : T20210730002 / OP_INDEX : 540 / SECTION : 0 -  조건 통과
# OP_TYPE:4 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 541 / SECTION : 0 -  데이터 선택 (28)
# SHIP_ID : T20210730002 / OP_INDEX : 542 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 543 / SECTION : 0 -  데이터 선택 (65)
# SHIP_ID : T20210730002 / OP_INDEX : 544 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 545 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 546 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 547 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 548 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 550 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210730002 / OP_INDEX : 551 / SECTION : 0 -  데이터 선택 (38)
# SHIP_ID : T20210730002 / OP_INDEX : 552 / SECTION : 0 -  데이터 선택 (63)
# SHIP_ID : T20210730002 / OP_INDEX : 553 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 554 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 555 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 556 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 557 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 559 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 560 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 561 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 562 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 563 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210730002 / OP_INDEX : 564 / SECTION : 0 -  데이터 선택 (3)
# SHIP_ID : T20210730002 / OP_INDEX : 565 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210730002 / OP_INDEX : 566 / SECTION : 0 -  데이터 선택 (19)
# SHIP_ID : T20210730002 / OP_INDEX : 567 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210730002 / OP_INDEX : 568 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210730002 / OP_INDEX : 569 / SECTION : 0 -  데이터 선택 (111)
# SHIP_ID : T20210730002 / OP_INDEX : 569 / SECTION : 0 -  조건 통과
# OP_TYPE:2 이기에 패스합니다.
# SHIP_ID : T20210730002 / OP_INDEX : 570 / SECTION : 0 -  데이터 선택 (8)
# SHIP_ID : T20210730002 / OP_INDEX : 571 / SECTION : 0 -  데이터 선택 (54)
# SHIP_ID : T20210730002 / OP_INDEX : 572 / SECTION : 0 -  데이터 선택 (464)
# SHIP_ID : T20210730002 / OP_INDEX : 572 / SECTION : 0 -  조건 통과
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:782, in Connection._read_bytes(self, num_bytes)
#     781 try:
# --> 782     data = self._rfile.read(num_bytes)
#     783     break
#
# File ~\AppData\Local\Programs\Python\Python38\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:1127, in Connection._rollback_impl(self)
#    1126 try:
# -> 1127     self.engine.dialect.do_rollback(self.connection)
#    1128 except BaseException as e:
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\default.py:699, in DefaultDialect.do_rollback(self, dbapi_connection)
#     698 def do_rollback(self, dbapi_connection):
# --> 699     dbapi_connection.rollback()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:493, in Connection.rollback(self)
#     492 self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
# --> 493 self._read_ok_packet()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:453, in Connection._read_ok_packet(self)
#     452 def _read_ok_packet(self):
# --> 453     pkt = self._read_packet()
#     454     if not pkt.is_ok_packet():
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:744, in Connection._read_packet(self, packet_type)
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:788, in Connection._read_bytes(self, num_bytes)
#     787     self._force_close()
# --> 788     raise err.OperationalError(
#     789         CR.CR_SERVER_LOST,
#     790         f"Lost connection to MySQL server during query ({e})",
#     791     )
#     792 except BaseException:
#     793     # Don't convert unknown exception to MySQLError.
#
# OperationalError: (2013, 'Lost connection to MySQL server during query ([WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 16
#      14 print(f'SHIP_ID : {ship_id} / OP_INDEX : {op_index} / SECTION : {section} -  조건 통과')
#      15 try:
# ---> 16     apply_system_health_algorithms_with_csu(ship_id,op_index,section)
#      17 except ValueError as e :
#      18     print(f'에러 발생: {e}. 다음 반복으로 넘어갑니다.')
#
# File ~\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\update_package\csu_system_health_algorithms.py:169, in apply_system_health_algorithms_with_csu(ship_id, op_index, section)
#     163 """ 인자: 선박 이름, 오퍼레이션 번호, 섹션 번호
#     164
#     165     반환 값: 오퍼레이션 실시간 건강도 데이터 자동적재, 오퍼레이션 건강도 그룹 자동적재
#     166 """
#     168 # 데이터 로드
# --> 169 df = get_dataframe_from_database(ship_id,op_index,section)
#     170 optime = get_dataframe_from_database_optime(ship_id,op_index)
#     172 df = df[['SHIP_ID','OP_INDEX','SECTION','DATA_TIME','DATA_INDEX','CSU','STS','FTS','FMU','TRO','ANU','RATE','CURRENT','VOLTAGE']]
#
# File ~\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\update_package\select_dataset.py:33, in get_dataframe_from_database(ship_id, op_index, section, total)
#      30 query = f"SELECT * FROM `{table_name}` WHERE `SHIP_ID` = '{ship_id}'AND `OP_INDEX` = '{op_index}' AND `SECTION` = '{section}';"
#      32 # Pandas를 사용하여 데이터 프레임으로 로드
# ---> 33 df = pd.read_sql(query, engine)
#      35 return df
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pandas\io\sql.py:663, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     653     return pandas_sql.read_table(
#     654         sql,
#     655         index_col=index_col,
#    (...)
#     660         dtype_backend=dtype_backend,
#     661     )
#     662 else:
# --> 663     return pandas_sql.read_query(
#     664         sql,
#     665         index_col=index_col,
#     666         params=params,
#     667         coerce_float=coerce_float,
#     668         parse_dates=parse_dates,
#     669         chunksize=chunksize,
#     670         dtype_backend=dtype_backend,
#     671         dtype=dtype,
#     672     )
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pandas\io\sql.py:1548, in SQLDatabase.__exit__(self, *args)
#    1546 def __exit__(self, *args) -> None:
#    1547     if not self.returns_generator:
# -> 1548         self.exit_stack.close()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py:533, in ExitStack.close(self)
#     531 def close(self):
#     532     """Immediately unwind the context stack."""
# --> 533     self.__exit__(None, None, None)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py:525, in ExitStack.__exit__(self, *exc_details)
#     521 try:
#     522     # bare "raise exc_details[1]" replaces our carefully
#     523     # set-up context
#     524     fixed_ctx = exc_details[1].__context__
# --> 525     raise exc_details[1]
#     526 except BaseException:
#     527     exc_details[1].__context__ = fixed_ctx
#
# File ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py:510, in ExitStack.__exit__(self, *exc_details)
#     508 assert is_sync
#     509 try:
# --> 510     if cb(*exc_details):
#     511         suppressed_exc = True
#     512         pending_raise = False
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:235, in Connection.__exit__(self, type_, value, traceback)
#     234 def __exit__(self, type_: Any, value: Any, traceback: Any) -> None:
# --> 235     self.close()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:1242, in Connection.close(self)
#    1219 """Close this :class:`_engine.Connection`.
#    1220
#    1221 This results in a release of the underlying database
#    (...)
#    1238
#    1239 """
#    1241 if self._transaction:
# -> 1242     self._transaction.close()
#    1243     skip_reset = True
#    1244 else:
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:2588, in Transaction.close(self)
#    2577 """Close this :class:`.Transaction`.
#    2578
#    2579 If this transaction is the base transaction in a begin/commit
#    (...)
#    2585
#    2586 """
#    2587 try:
# -> 2588     self._do_close()
#    2589 finally:
#    2590     assert not self.is_active
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:2726, in RootTransaction._do_close(self)
#    2725 def _do_close(self) -> None:
# -> 2726     self._close_impl()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:2712, in RootTransaction._close_impl(self, try_deactivate)
#    2710 try:
#    2711     if self.is_active:
# -> 2712         self._connection_rollback_impl()
#    2714     if self.connection._nested_transaction:
#    2715         self.connection._nested_transaction._cancel()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:2704, in RootTransaction._connection_rollback_impl(self)
#    2703 def _connection_rollback_impl(self) -> None:
# -> 2704     self.connection._rollback_impl()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:1129, in Connection._rollback_impl(self)
#    1127     self.engine.dialect.do_rollback(self.connection)
#    1128 except BaseException as e:
# -> 1129     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\base.py:1127, in Connection._rollback_impl(self)
#    1125         self._log_info("ROLLBACK")
#    1126 try:
# -> 1127     self.engine.dialect.do_rollback(self.connection)
#    1128 except BaseException as e:
#    1129     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\sqlalchemy\engine\default.py:699, in DefaultDialect.do_rollback(self, dbapi_connection)
#     698 def do_rollback(self, dbapi_connection):
# --> 699     dbapi_connection.rollback()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:493, in Connection.rollback(self)
#     486 """
#     487 Roll back the current transaction.
#     488
#     489 See `Connection.rollback() <https://www.python.org/dev/peps/pep-0249/#rollback>`_
#     490 in the specification.
#     491 """
#     492 self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
# --> 493 self._read_ok_packet()
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:453, in Connection._read_ok_packet(self)
#     452 def _read_ok_packet(self):
# --> 453     pkt = self._read_packet()
#     454     if not pkt.is_ok_packet():
#     455         raise err.OperationalError(
#     456             CR.CR_COMMANDS_OUT_OF_SYNC,
#     457             "Command Out of Sync",
#     458         )
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:744, in Connection._read_packet(self, packet_type)
#     742 buff = bytearray()
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#     747     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~\Desktop\프로젝트\테크로스\시스템건강도\myenv\lib\site-packages\pymysql\connections.py:788, in Connection._read_bytes(self, num_bytes)
#     786         continue
#     787     self._force_close()
# --> 788     raise err.OperationalError(
#     789         CR.CR_SERVER_LOST,
#     790         f"Lost connection to MySQL server during query ({e})",
#     791     )
#     792 except BaseException:
#     793     # Don't convert unknown exception to MySQLError.
#     794     self._force_close()
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query ([WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
