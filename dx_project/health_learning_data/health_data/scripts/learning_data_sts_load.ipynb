# %%
from update_package.sts_system_health_algorithms import apply_system_health_algorithms_with_sts
from update_package.select_dataset import get_dataframe_from_database
from update_package.load_database import load_database

import pandas as pd

# %%
# Goals: 정상 데이터 목록화

#latest_data = pd.read_csv(r"C:\Users\pc021\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\data\latest\ecs_data.csv")
data = pd.read_csv(r"C:\Users\pc021\Desktop\프로젝트\테크로스\모델 고도화\건강도 데이터\data\ecs_DATA.csv")

#grouped_latest_data = latest_data.groupby(['SHIP_ID','OP_INDEX','SECTION']).count() 
#grouped_latest_index = grouped_latest_data.index

grouped_data = data.groupby(['SHIP_ID','OP_INDEX','SECTION']).count() 
grouped_index = grouped_data.index

#multiindex2_without_overlap = grouped_latest_index.difference(grouped_index)

# %%
datas = pd.DataFrame(index = grouped_index).reset_index()
datas[(datas['SHIP_ID']=='T99990000006') & (datas['OP_INDEX']==13) & (datas['SECTION']==0)]
# Out:
#             SHIP_ID  OP_INDEX  SECTION
# 51242  T99990000006        13        0

# %%
for index in grouped_index[34354:]:
    ship_id = index[0]
    op_index = index[1]
    section = index[2] 
    
    #data = get_dataframe_from_database(ship_id,op_index,section)
    df = data[(data['SHIP_ID']==ship_id) & (data['OP_INDEX']==op_index) & (data['SECTION']==section)]
    
    data_len = len(df)
    print(f'SHIP_ID : {ship_id} / OP_INDEX : {op_index} / SECTION : {section} -  데이터 선택 ({data_len})')
    
    if (data_len>=100) :
        print(f'SHIP_ID : {ship_id} / OP_INDEX : {op_index} / SECTION : {section} -  조건 통과')
        #apply_system_health_algorithms_with_fts(ship_id,op_index,section)
        try:
            apply_system_health_algorithms_with_sts(ship_id,op_index,section)
        except ValueError as e :
            print(f'에러 발생: {e}. 다음 반복으로 넘어갑니다.')
            continue  # 에러 발생 시 다음 반복으로 넘어감\
            
        except KeyError as e :
            print(f'에러 발생: {e}. 다음 반복으로 넘어갑니다.')
            continue  # 에러 발생 시 다음 반복으로 넘어감
# Out:
# SHIP_ID : T20210525001 / OP_INDEX : 244 / SECTION : 0 -  데이터 선택 (323)
# SHIP_ID : T20210525001 / OP_INDEX : 244 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 245 / SECTION : 0 -  데이터 선택 (13)
# SHIP_ID : T20210525001 / OP_INDEX : 246 / SECTION : 0 -  데이터 선택 (81)
# SHIP_ID : T20210525001 / OP_INDEX : 247 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T20210525001 / OP_INDEX : 248 / SECTION : 0 -  데이터 선택 (19)
# SHIP_ID : T20210525001 / OP_INDEX : 249 / SECTION : 0 -  데이터 선택 (6)
# SHIP_ID : T20210525001 / OP_INDEX : 250 / SECTION : 0 -  데이터 선택 (22)
# SHIP_ID : T20210525001 / OP_INDEX : 251 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 252 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T20210525001 / OP_INDEX : 253 / SECTION : 0 -  데이터 선택 (80)
# SHIP_ID : T20210525001 / OP_INDEX : 254 / SECTION : 0 -  데이터 선택 (117)
# SHIP_ID : T20210525001 / OP_INDEX : 254 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 255 / SECTION : 0 -  데이터 선택 (6)
# SHIP_ID : T20210525001 / OP_INDEX : 256 / SECTION : 0 -  데이터 선택 (32)
# SHIP_ID : T20210525001 / OP_INDEX : 257 / SECTION : 0 -  데이터 선택 (784)
# SHIP_ID : T20210525001 / OP_INDEX : 257 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 258 / SECTION : 0 -  데이터 선택 (205)
# SHIP_ID : T20210525001 / OP_INDEX : 258 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 259 / SECTION : 0 -  데이터 선택 (352)
# SHIP_ID : T20210525001 / OP_INDEX : 259 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 260 / SECTION : 0 -  데이터 선택 (43)
# SHIP_ID : T20210525001 / OP_INDEX : 261 / SECTION : 0 -  데이터 선택 (117)
# SHIP_ID : T20210525001 / OP_INDEX : 261 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 262 / SECTION : 0 -  데이터 선택 (921)
# SHIP_ID : T20210525001 / OP_INDEX : 262 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 263 / SECTION : 0 -  데이터 선택 (61)
# SHIP_ID : T20210525001 / OP_INDEX : 264 / SECTION : 0 -  데이터 선택 (420)
# SHIP_ID : T20210525001 / OP_INDEX : 264 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 265 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210525001 / OP_INDEX : 266 / SECTION : 0 -  데이터 선택 (447)
# SHIP_ID : T20210525001 / OP_INDEX : 266 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 286 / SECTION : 0 -  데이터 선택 (186)
# SHIP_ID : T20210525001 / OP_INDEX : 286 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 287 / SECTION : 0 -  데이터 선택 (276)
# SHIP_ID : T20210525001 / OP_INDEX : 287 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 288 / SECTION : 0 -  데이터 선택 (4498)
# SHIP_ID : T20210525001 / OP_INDEX : 288 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 290 / SECTION : 0 -  데이터 선택 (1063)
# SHIP_ID : T20210525001 / OP_INDEX : 290 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 292 / SECTION : 0 -  데이터 선택 (306)
# SHIP_ID : T20210525001 / OP_INDEX : 292 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 295 / SECTION : 0 -  데이터 선택 (294)
# SHIP_ID : T20210525001 / OP_INDEX : 295 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 301 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 302 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T20210525001 / OP_INDEX : 304 / SECTION : 0 -  데이터 선택 (28)
# SHIP_ID : T20210525001 / OP_INDEX : 307 / SECTION : 0 -  데이터 선택 (215)
# SHIP_ID : T20210525001 / OP_INDEX : 307 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 308 / SECTION : 0 -  데이터 선택 (40)
# SHIP_ID : T20210525001 / OP_INDEX : 309 / SECTION : 0 -  데이터 선택 (250)
# SHIP_ID : T20210525001 / OP_INDEX : 309 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210525001 / OP_INDEX : 314 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 315 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 316 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 317 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 319 / SECTION : 0 -  데이터 선택 (5)
# SHIP_ID : T20210525001 / OP_INDEX : 320 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 322 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 326 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 328 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 329 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 330 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 331 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 333 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 334 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210525001 / OP_INDEX : 340 / SECTION : 0 -  데이터 선택 (286)
# SHIP_ID : T20210525001 / OP_INDEX : 340 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 341 / SECTION : 0 -  데이터 선택 (85)
# SHIP_ID : T20210525001 / OP_INDEX : 346 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T20210525001 / OP_INDEX : 347 / SECTION : 0 -  데이터 선택 (28)
# SHIP_ID : T20210525001 / OP_INDEX : 351 / SECTION : 0 -  데이터 선택 (159)
# SHIP_ID : T20210525001 / OP_INDEX : 351 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 353 / SECTION : 0 -  데이터 선택 (38)
# SHIP_ID : T20210525001 / OP_INDEX : 355 / SECTION : 0 -  데이터 선택 (878)
# SHIP_ID : T20210525001 / OP_INDEX : 355 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 356 / SECTION : 0 -  데이터 선택 (31)
# SHIP_ID : T20210525001 / OP_INDEX : 357 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T20210525001 / OP_INDEX : 358 / SECTION : 0 -  데이터 선택 (14)
# SHIP_ID : T20210525001 / OP_INDEX : 359 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T20210525001 / OP_INDEX : 360 / SECTION : 0 -  데이터 선택 (77)
# SHIP_ID : T20210525001 / OP_INDEX : 361 / SECTION : 0 -  데이터 선택 (147)
# SHIP_ID : T20210525001 / OP_INDEX : 361 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 362 / SECTION : 0 -  데이터 선택 (75)
# SHIP_ID : T20210525001 / OP_INDEX : 363 / SECTION : 0 -  데이터 선택 (117)
# SHIP_ID : T20210525001 / OP_INDEX : 363 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210525001 / OP_INDEX : 364 / SECTION : 0 -  데이터 선택 (83)
# SHIP_ID : T20210525001 / OP_INDEX : 366 / SECTION : 0 -  데이터 선택 (11)
# SHIP_ID : T20210525001 / OP_INDEX : 367 / SECTION : 0 -  데이터 선택 (54)
# SHIP_ID : T20
/ SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 136 / SECTION : 0 -  데이터 선택 (91)
# SHIP_ID : T20210609008 / OP_INDEX : 137 / SECTION : 0 -  데이터 선택 (107)
# SHIP_ID : T20210609008 / OP_INDEX : 137 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 138 / SECTION : 0 -  데이터 선택 (116)
# SHIP_ID : T20210609008 / OP_INDEX : 138 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 139 / SECTION : 0 -  데이터 선택 (121)
# SHIP_ID : T20210609008 / OP_INDEX : 139 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 140 / SECTION : 0 -  데이터 선택 (291)
# SHIP_ID : T20210609008 / OP_INDEX : 140 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 141 / SECTION : 0 -  데이터 선택 (432)
# SHIP_ID : T20210609008 / OP_INDEX : 141 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 142 / SECTION : 0 -  데이터 선택 (469)
# SHIP_ID : T20210609008 / OP_INDEX : 142 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 143 / SECTION : 0 -  데이터 선택 (262)
# SHIP_ID : T20210609008 / OP_INDEX : 143 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 144 / SECTION : 0 -  데이터 선택 (272)
# SHIP_ID : T20210609008 / OP_INDEX : 144 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 145 / SECTION : 0 -  데이터 선택 (342)
# SHIP_ID : T20210609008 / OP_INDEX : 145 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 146 / SECTION : 0 -  데이터 선택 (339)
# SHIP_ID : T20210609008 / OP_INDEX : 146 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 148 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 149 / SECTION : 0 -  데이터 선택 (298)
# SHIP_ID : T20210609008 / OP_INDEX : 149 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 150 / SECTION : 0 -  데이터 선택 (71)
# SHIP_ID : T20210609008 / OP_INDEX : 151 / SECTION : 0 -  데이터 선택 (677)
# SHIP_ID : T20210609008 / OP_INDEX : 151 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 152 / SECTION : 0 -  데이터 선택 (180)
# SHIP_ID : T20210609008 / OP_INDEX : 152 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 154 / SECTION : 0 -  데이터 선택 (648)
# SHIP_ID : T20210609008 / OP_INDEX : 154 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 155 / SECTION : 0 -  데이터 선택 (13)
# SHIP_ID : T20210609008 / OP_INDEX : 156 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 157 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 158 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 159 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 160 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 161 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T20210609008 / OP_INDEX : 162 / SECTION : 0 -  데이터 선택 (3)
# SHIP_ID : T20210609008 / OP_INDEX : 163 / SECTION : 0 -  데이터 선택 (316)
# SHIP_ID : T20210609008 / OP_INDEX : 163 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 164 / SECTION : 0 -  데이터 선택 (188)
# SHIP_ID : T20210609008 / OP_INDEX : 164 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 165 / SECTION : 0 -  데이터 선택 (399)
# SHIP_ID : T20210609008 / OP_INDEX : 165 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 166 / SECTION : 0 -  데이터 선택 (177)
# SHIP_ID : T20210609008 / OP_INDEX : 166 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T20210609008 / OP_INDEX : 167 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T20210609008 / OP_INDEX : 168 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T20210609008 / OP_INDEX : 169 / SECTION : 0 -  데이터 선택 (247)
# SHIP_ID : T20210609008 / OP_INDEX : 169 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 170 / SECTION : 0 -  데이터 선택 (239)
# SHIP_ID : T20210609008 / OP_INDEX : 170 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 171 / SECTION : 0 -  데이터 선택 (147)
# SHIP_ID : T20210609008 / OP_INDEX : 171 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 172 / SECTION : 0 -  데이터 선택 (129)
# SHIP_ID : T20210609008 / OP_INDEX : 172 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 173 / SECTION : 0 -  데이터 선택 (83)
# SHIP_ID : T20210609008 / OP_INDEX : 174 / SECTION : 0 -  데이터 선택 (122)
# SHIP_ID : T20210609008 / OP_INDEX : 174 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 175 / SECTION : 0 -  데이터 선택 (121)
# SHIP_ID : T20210609008 / OP_INDEX : 175 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 176 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210609008 / OP_INDEX : 177 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T20210609008 / OP_INDEX : 178 / SECTION : 0 -  데이터 선택 (24)
# SHIP_ID : T20210609008 / OP_INDEX : 179 / SECTION : 0 -  데이터 선택 (136)
# SHIP_ID : T20210609008 / OP_INDEX : 179 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX : 180 / SECTION : 0 -  데이터 선택 (17)
# SHIP_ID : T20210609008 / OP_INDEX : 181 / SECTION : 0 -  데이터 선택 (119)
# SHIP_ID : T20210609008 / OP_INDEX : 181 / SECTION : 0 -  조건 통과
# SHIP_ID : T20210609008 / OP_INDEX :
/ SECTION : 0 -  데이터 선택 (17)
# SHIP_ID : T99990000004 / OP_INDEX : 358 / SECTION : 0 -  데이터 선택 (195)
# SHIP_ID : T99990000004 / OP_INDEX : 358 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 359 / SECTION : 0 -  데이터 선택 (195)
# SHIP_ID : T99990000004 / OP_INDEX : 359 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 360 / SECTION : 0 -  데이터 선택 (195)
# SHIP_ID : T99990000004 / OP_INDEX : 360 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 361 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000004 / OP_INDEX : 362 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000004 / OP_INDEX : 363 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000004 / OP_INDEX : 364 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T99990000004 / OP_INDEX : 365 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T99990000004 / OP_INDEX : 366 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T99990000004 / OP_INDEX : 367 / SECTION : 0 -  데이터 선택 (159)
# SHIP_ID : T99990000004 / OP_INDEX : 367 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 368 / SECTION : 0 -  데이터 선택 (159)
# SHIP_ID : T99990000004 / OP_INDEX : 368 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 369 / SECTION : 0 -  데이터 선택 (160)
# SHIP_ID : T99990000004 / OP_INDEX : 369 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 370 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T99990000004 / OP_INDEX : 371 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T99990000004 / OP_INDEX : 372 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T99990000004 / OP_INDEX : 373 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T99990000004 / OP_INDEX : 374 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T99990000004 / OP_INDEX : 375 / SECTION : 0 -  데이터 선택 (119)
# SHIP_ID : T99990000004 / OP_INDEX : 375 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 376 / SECTION : 0 -  데이터 선택 (119)
# SHIP_ID : T99990000004 / OP_INDEX : 376 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 377 / SECTION : 0 -  데이터 선택 (119)
# SHIP_ID : T99990000004 / OP_INDEX : 377 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 378 / SECTION : 0 -  데이터 선택 (26)
# SHIP_ID : T99990000004 / OP_INDEX : 379 / SECTION : 0 -  데이터 선택 (31)
# SHIP_ID : T99990000004 / OP_INDEX : 380 / SECTION : 0 -  데이터 선택 (31)
# SHIP_ID : T99990000004 / OP_INDEX : 381 / SECTION : 0 -  데이터 선택 (31)
# SHIP_ID : T99990000004 / OP_INDEX : 382 / SECTION : 0 -  데이터 선택 (123)
# SHIP_ID : T99990000004 / OP_INDEX : 382 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 383 / SECTION : 0 -  데이터 선택 (123)
# SHIP_ID : T99990000004 / OP_INDEX : 383 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 384 / SECTION : 0 -  데이터 선택 (123)
# SHIP_ID : T99990000004 / OP_INDEX : 384 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 385 / SECTION : 0 -  데이터 선택 (3)
# SHIP_ID : T99990000004 / OP_INDEX : 386 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000004 / OP_INDEX : 387 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000004 / OP_INDEX : 388 / SECTION : 0 -  데이터 선택 (90)
# SHIP_ID : T99990000004 / OP_INDEX : 389 / SECTION : 0 -  데이터 선택 (90)
# SHIP_ID : T99990000004 / OP_INDEX : 390 / SECTION : 0 -  데이터 선택 (90)
# SHIP_ID : T99990000004 / OP_INDEX : 391 / SECTION : 0 -  데이터 선택 (275)
# SHIP_ID : T99990000004 / OP_INDEX : 391 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 392 / SECTION : 0 -  데이터 선택 (275)
# SHIP_ID : T99990000004 / OP_INDEX : 392 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 393 / SECTION : 0 -  데이터 선택 (275)
# SHIP_ID : T99990000004 / OP_INDEX : 393 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 394 / SECTION : 0 -  데이터 선택 (22)
# SHIP_ID : T99990000004 / OP_INDEX : 395 / SECTION : 0 -  데이터 선택 (22)
# SHIP_ID : T99990000004 / OP_INDEX : 396 / SECTION : 0 -  데이터 선택 (22)
# SHIP_ID : T99990000004 / OP_INDEX : 397 / SECTION : 0 -  데이터 선택 (45)
# SHIP_ID : T99990000004 / OP_INDEX : 398 / SECTION : 0 -  데이터 선택 (45)
# SHIP_ID : T99990000004 / OP_INDEX : 399 / SECTION : 0 -  데이터 선택 (9)
# SHIP_ID : T99990000004 / OP_INDEX : 400 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T99990000004 / OP_INDEX : 401 / SECTION : 0 -  데이터 선택 (10)
# SHIP_ID : T99990000004 / OP_INDEX : 402 / SECTION : 0 -  데이터 선택 (170)
# SHIP_ID : T99990000004 / OP_INDEX : 402 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 403 / SECTION : 0 -  데이터 선택 (170)
# SHIP_ID : T99990000004 / OP_INDEX : 403 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 404 / SECTION : 0 -  데이터 선택 (170)
# SHIP_ID : T99990000004 / OP_INDEX : 404 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 405 / SECTION : 0 -  데이터 선택 (125)
# SHIP_ID : T99990000004 / OP_INDEX : 405 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 406 / SECTION : 0 -  데이터 선택 (125)
# SHIP_ID : T99990000004 / OP_INDEX : 406 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 407 / SECTION : 0 -  데이터 선택 (125)
# SHIP_ID : T99990000004 / OP_INDEX : 407 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 408 / SECTION : 0 -  데이터 선택 (478)
# SHIP_ID : T99990000004 / OP_INDEX : 408 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 409 / SECTION : 0 -  데이터 선택 (479)
# SHIP_ID : T99990000004 / OP_INDEX : 409 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 410 / SECTION : 0 -  데이터 선택 (479)
# SHIP_ID : T99990000004 / OP_INDEX : 410 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 411 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T99990000004 / OP_INDEX : 412 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T99990000004 / OP_INDEX : 413 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T99990000004 / OP_INDEX : 414 / SECTION : 0 -  데이터 선택 (110)
# SHIP_ID : T99990000004 / OP_INDEX : 414 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000004 / OP_INDEX : 415 / SECTION : 0 -  데이터 선택 (110)
# SHIP_ID : T99990000004 / OP_INDEX : 415 / SECTION : 0 -  조건 통과
# DataFrame has been successfully loaded into tc_ai_sts_system_health table in ecs_test database.
# Database connection closed.
# DataFrame has been successfully loaded into tc_ai_sts_system_health_group table in ecs_test database.
# Database connection closed.
# SHIP_ID : T99990000006 / OP_INDEX : 1 / SECTION : 0 -  데이터 선택 (7)
# SHIP_ID : T99990000006 / OP_INDEX : 2 / SECTION : 0 -  데이터 선택 (8)
# SHIP_ID : T99990000006 / OP_INDEX : 3 / SECTION : 0 -  데이터 선택 (1)
# SHIP_ID : T99990000006 / OP_INDEX : 4 / SECTION : 0 -  데이터 선택 (17)
# SHIP_ID : T99990000006 / OP_INDEX : 6 / SECTION : 0 -  데이터 선택 (2)
# SHIP_ID : T99990000006 / OP_INDEX : 9 / SECTION : 0 -  데이터 선택 (12)
# SHIP_ID : T99990000006 / OP_INDEX : 10 / SECTION : 0 -  데이터 선택 (4)
# SHIP_ID : T99990000006 / OP_INDEX : 13 / SECTION : 0 -  데이터 선택 (3)
# SHIP_ID : Unknown / OP_INDEX : 1 / SECTION : 2 -  데이터 선택 (4)
# SHIP_ID : Unknown / OP_INDEX : 2 / SECTION : 2 -  데이터 선택 (4)
# SHIP_ID : Unknown / OP_INDEX : 3 / SECTION : 2 -  데이터 선택 (4)
# SHIP_ID : UnkownShip / OP_INDEX : 1 / SECTION : 2 -  데이터 선택 (11)
# SHIP_ID : UnkownShip / OP_INDEX : 2 / SECTION : 2 -  데이터 선택 (4)
# SHIP_ID : UnkownShip / OP_INDEX : 3 / SECTION : 2 -  데이터 선택 (4)
# SHIP_ID : UnkownShip / OP_INDEX : 4 / SECTION : 2 -  데이터 선택 (12)
# SHIP_ID : UnkownShip / OP_INDEX : 5 / SECTION : 2 -  데이터 선택 (3)
